# %% [markdown]
# <a href="https://colab.research.google.com/github/Whiteomi/Hola_Mundo/blob/main/1_Extracci%C3%B3n_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerias requeridad 
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as  plt
import seaborn as sns
import io

# %%
#Cargar archivo csv desde seaborn
from google.colab import files 
files.upload()

# %%
#Convertir en dataframe 
df= pd.read_csv("file.csv")
df
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0        2005          1           Nacional  Hombres
# 1        2005          1           Nacional  Mujeres
# 2        2005          1     Aguascalientes  Hombres
# 3        2005          1     Aguascalientes  Mujeres
# 4        2005          1    Baja California  Hombres
# ...       ...        ...                ...      ...
# 4549     2022          1           Veracruz  Mujeres
# 4550     2022          1            Yucat n  Hombres
# 4551     2022          1            Yucat n  Mujeres
# 4552     2022          1          Zacatecas  Hombres
# 4553     2022          1          Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                            4384907          26597801
# 1                                            2690296          14843275
# 2                                              56407            246177
# ...

# %%
#Imprimimos las primras filas o registros del Dataframe 
df.head(5)
# Out:
#    Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0     2005          1           Nacional  Hombres
# 1     2005          1           Nacional  Mujeres
# 2     2005          1     Aguascalientes  Hombres
# 3     2005          1     Aguascalientes  Mujeres
# 4     2005          1    Baja California  Hombres
#
#   Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                         4384907          26597801
# 1                                         2690296          14843275
# 2                                           56407            246177
# 3                                           28430            145656
# 4                                          167651            768989
#
#   Tasa_de_ocupaci n_en_la_industria_manufacturera
# 0                        16.485975660000000000000
# 1                        18.124679360000000000000
# 2                        22.913188480000000000000
# ...

# %%
#Filtro por objeto 
filtro1=df[df["Sexo"] =="Mujeres"]
filtro1
# Out:
#       Periodo  Trimestre   Entidad_Federativa     Sexo  \
# 1        2005          1             Nacional  Mujeres
# 3        2005          1       Aguascalientes  Mujeres
# 5        2005          1      Baja California  Mujeres
# 7        2005          1  Baja California Sur  Mujeres
# 9        2005          1             Campeche  Mujeres
# ...       ...        ...                  ...      ...
# 4545     2022          1           Tamaulipas  Mujeres
# 4547     2022          1             Tlaxcala  Mujeres
# 4549     2022          1             Veracruz  Mujeres
# 4551     2022          1              Yucat n  Mujeres
# 4553     2022          1            Zacatecas  Mujeres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 1                                            2690296          14843275
# 3                                              28430            145656
# 5                                             103697            398911
# ...

# %%
#Filtro por filas 
filtro2= df.iloc[0:99,: ]
#filtro2=df.iloc[[1000, 2000, 3000], :] #filas no consecutivas 
filtro2
# Out:
#     Periodo  Trimestre Entidad_Federativa     Sexo  \
# 0      2005          1           Nacional  Hombres
# 1      2005          1           Nacional  Mujeres
# 2      2005          1     Aguascalientes  Hombres
# 3      2005          1     Aguascalientes  Mujeres
# 4      2005          1    Baja California  Hombres
# ..      ...        ...                ...      ...
# 94     2005          2            Jalisco  Hombres
# 95     2005          2            Jalisco  Mujeres
# 96     2005          2             M xico  Hombres
# 97     2005          2             M xico  Mujeres
# 98     2005          2          Michoac n  Hombres
#
#    Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 0                                          4384907          26597801
# 1                                          2690296          14843275
# 2                                            56407            246177
# 3                                            28430            145656
# ...

# %%
#Filtro por columnas 
#filtro3=df.iloc[ : , 4:6]
filtro3=df.iloc[ : , [1,4,6]] #columnas no consecutivas 
filtro3
# Out:
#       Trimestre Poblacion_ocupada_en_la_industria_manufacturera  \
# 0             1                                         4384907
# 1             1                                         2690296
# 2             1                                           56407
# 3             1                                           28430
# 4             1                                          167651
# ...         ...                                             ...
# 4549          1                                          107640
# 4550          1                                          101992
# 4551          1                                           82759
# 4552          1                                           44105
# 4553          1                                           39472
#
#      Tasa_de_ocupaci n_en_la_industria_manufacturera
# 0                           16.485975660000000000000
# 1                           18.124679360000000000000
# ...

# %%
#Filtro por columnas y por filas 
filtro_mix=df.iloc[ [10,20,50] , 2:5]
#filtro3=df.iloc[ : , [1,4,6]] #columnas no consecutivas 
filtro_mix
# Out:
#                        Sexo Poblacion_ocupada_en_la_industria_manufacturera  \
# Entidad_Federativa
# Coahuila            Hombres                                          171196
# Durango             Hombres                                           65926
# Sinaloa             Hombres                                           77990
#
#                    Poblaci n_ocupada
# Entidad_Federativa
# Coahuila                      636756
# Durango                       378399
# Sinaloa                       749476

# %%
#Filtro de filas vs columnas 
#Paso 1: Leemos el contenido del archivo 
from google.colab import files 
uploaded=files.upload()
df = pd.read_csv(io.BytesIO(uploaded['file.csv']),index_col=2)
df
# Out:
#      <input type="file" id="files-9695f8da-1af4-4031-a20d-ba719f2071bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9695f8da-1af4-4031-a20d-ba719f2071bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Paso 2: Aplicamos filtro de filas vs columnas 
filtro4=df.loc[["Puebla","Oaxaca","Veracruz","Guerrero"], ["Poblacion_ocupada_en_la_industria_manufacturera"]]
filtro4
# Out:
#                    Poblacion_ocupada_en_la_industria_manufacturera
# Entidad_Federativa
# Puebla                                                      230487
# Puebla                                                      188720
# Puebla                                                      236459
# Puebla                                                      190831
# Puebla                                                      233484
# ...                                                            ...
# Guerrero                                                     91799
# Guerrero                                                     59920
# Guerrero                                                     70838
# Guerrero                                                     65484
# Guerrero                                                     70182
#
# [552 rows x 1 columns]

# %%
#Filtro por cabecera 
filtro5=df.head()
filtro5
# Out:
#                     Periodo  Trimestre     Sexo  \
# Entidad_Federativa
# Nacional               2005          1  Hombres
# Nacional               2005          1  Mujeres
# Aguascalientes         2005          1  Hombres
# Aguascalientes         2005          1  Mujeres
# Baja California        2005          1  Hombres
#
#                    Poblacion_ocupada_en_la_industria_manufacturera  \
# Entidad_Federativa
# Nacional                                                   4384907
# Nacional                                                   2690296
# Aguascalientes                                               56407
# Aguascalientes                                               28430
# Baja California                                             167651
#
#                    Poblaci n_ocupada  \
# Entidad_Federativa
# Nacional                    26597801
# Nacional                    14843275
# Aguascalientes                246177
# Aguascalientes                145656
# ...

# %%
#Filtro por comparacion 
filtro6=df[df["Periodo"] >= 2010]
filtro6
# Out:
#                     Periodo  Trimestre     Sexo  \
# Entidad_Federativa
# Nacional               2010          1  Hombres
# Nacional               2010          1  Mujeres
# Aguascalientes         2010          1  Hombres
# Aguascalientes         2010          1  Mujeres
# Baja California        2010          1  Hombres
# ...                     ...        ...      ...
# Veracruz               2022          1  Mujeres
# Yucat n                2022          1  Hombres
# Yucat n                2022          1  Mujeres
# Zacatecas              2022          1  Hombres
# Zacatecas              2022          1  Mujeres
#
#                    Poblacion_ocupada_en_la_industria_manufacturera  \
# Entidad_Federativa
# Nacional                                                   4477317
# Nacional                                                   2580136
# Aguascalientes                                               58931
# Aguascalientes                                               30999
# ...

# %%
#Filtro Y 
filtro7=df[(df["Periodo"] == 2015) & (df["Sexo"] =="Hombres") & (df["Entidad_Federativa"] == "Puebla"	)]
filtro7
# Out:
#       Periodo  Trimestre Entidad_Federativa     Sexo  \
# 2682     2015          1             Puebla  Hombres
# 2748     2015          2             Puebla  Hombres
# 2814     2015          3             Puebla  Hombres
# 2880     2015          4             Puebla  Hombres
#
#      Poblacion_ocupada_en_la_industria_manufacturera Poblaci n_ocupada  \
# 2682                                          213571           1549409
# 2748                                          209708           1602273
# 2814                                          231235           1559704
# 2880                                          228012           1619413
#
#      Tasa_de_ocupaci n_en_la_industria_manufacturera
# 2682                        13.784029910000000000000
# 2748                        13.088156640000000000000
# 2814                        14.825569470000000000000
# 2880                        14.079916610000000000000
